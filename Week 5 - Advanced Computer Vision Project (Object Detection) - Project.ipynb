# %% [markdown]
# # Instructions
# - Some parts of the code are already done for you
# - You need to execute all the cells
# - You need to add the code where ever you see `"#### Add your code here ####"`
# - Marks are mentioned along with the cells

# %% [markdown]
# # Face detection
# Task is to predict the boundaries(mask) around the face in a given image.

# %% [markdown]
# ## Dataset
# Faces in images marked with bounding boxes. Have around 500 images with around 1100 faces manually tagged via bounding box.

# %% [markdown]
# ### Mount Google drive if you are using google colab
# - We recommend using Google Colab as you can face memory issues and longer runtimes while running on local

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Change current working directory to project folder (1 mark)

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.layers import Conv2D, Reshape, GlobalAveragePooling2D, Dense
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf #### Add your code here ####
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# ### Load the "images.npy" file (4 marks)
# - This file contains images with details of bounding boxes

# %%
import numpy as np
data = np.load("/content/drive/My Drive/Colab Notebooks/GL-AIML-Modules-PythonExcercise/10 Computer Vision/Week 5 - Advanced Computer Vision Project (Object Detection) - Learning Material - Project/images.npy", allow_pickle= True)

# %% [markdown]
# ### Check one sample from the loaded "images.npy" file  (4 marks)

# %%
data.shape
# Out:
# (409, 2)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data[100][0].shape
# Out:
# (720, 1280, 3)

# %%
#### Add your code here ####
from matplotlib import pyplot as plt

plt.imshow(data[102][0])
plt.show()

# %% [markdown]
# ### Set image dimensions   (2 marks)
# - Initialize image height, image width with value: 224

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224

# %% [markdown]
# ### Create features and labels
# - Here feature is the image
# - The label is the mask
# - Images will be stored in "X_train" array
# - Masks will be stored in "masks" array

# %%
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input

masks = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH))
X_train = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH, 3))
for index in range(data.shape[0]):
    img = data[index][0]
    img = cv2.resize(img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH), interpolation=cv2.INTER_CUBIC)
    try:
      img = img[:, :, :3]
    except:
      continue
    X_train[index] = preprocess_input(np.array(img, dtype=np.float32))
    for i in data[index][1]:
        x1 = int(i["points"][0]['x'] * IMAGE_WIDTH)
        x2 = int(i["points"][1]['x'] * IMAGE_WIDTH)
        y1 = int(i["points"][0]['y'] * IMAGE_HEIGHT)
        y2 = int(i["points"][1]['y'] * IMAGE_HEIGHT)
        masks[index][y1:y2, x1:x2] = 1

# %% [markdown]
# ### Print the shape of X_train and mask array  (1 mark)

# %%
X_train.shape #### Add your code here ####
# Out:
# (409, 224, 224, 3)

# %%
masks.shape #### Add your code here ####
# Out:
# (409, 224, 224)

# %% [markdown]
# ### Print a sample image and image array

# %%
from matplotlib import  pyplot

n = 13
print(X_train[n])
pyplot.imshow(X_train[n])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   ...
#   [ 0.58431375  0.7019608   0.74117649]
#   [ 0.34901965  0.4666667   0.50588238]
#   [ 0.25490201  0.37254906  0.41176474]]
#
#  [[ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   ...
#   [ 0.58431375  0.7019608   0.74117649]
#   [ 0.34901965  0.4666667   0.50588238]
#   [ 0.25490201  0.37254906  0.41176474]]
#
#  [[ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   [ 0.96862745  1.          0.99215686]
#   ...
#   [ 0.59215689  0.70980394  0.74901962]
#   [ 0.34901965  0.4666667   0.50588238]
#   [ 0.25490201  0.37254906  0.41176474]]
#
#  ...
#
#  [[ 0.29411769  0.3176471   0.36470592]
#   [ 0.26274514  0.27843142  0.35686278]
#   [ 0.53725493  0.56078434  0.65490198]
#   ...
#   [-0.43529409 -0.40392154 -0.38039213]
#   [-0.45098037 -0.41960782 -0.39607841]
#   [-0.47450978 -0.44313723 -0.41960782]]
#
#  [[ 0.03529418  0.06666672  0.09019613]
#   [-0.20784312 -0.19215685 -0.09803921]
#   [-0.06666666 -0.04313725  0.06666672]
#   ...
#   [-0.3098039  -0.27843136 -0.25490195]
#   [-0.60784316 -0.57647061 -0.5529412 ]
#   [-0.60000002 -0.56862748 -0.56862748]]
#
#  [[-0.05098039 -0.05098039  0.00392163]
#   [-0.50588238 -0.50588238 -0.51372552]
#   [ 0.20000005  0.27058828  0.39607847]
#   ...
#   [-0.36470586 -0.372549   -0.32549018]
#   [-0.10588235 -0.11372548 -0.06666666]
#   [-0.6156863  -0.62352943 -0.58431375]]]

# %%
pyplot.imshow(masks[n])

# %% [markdown]
# ## Create the model (10 marks)
# - Add MobileNet as model with below parameter values
#   - input_shape: IMAGE_HEIGHT, IMAGE_WIDTH, 3
#   - include_top: False
#   - alpha: 1.0
#   - weights: "imagenet"
# - Add UNET architecture layers
#   - This is the trickiest part of the project, you need to research and implement it correctly

# %%
EPOCHS = 50
BATCH_SIZE = 1
PATIENCE = 10
ALPHA = 1.0

HEIGHT_CELLS = 224
WIDTH_CELLS = 224

CELL_WIDTH = IMAGE_WIDTH / WIDTH_CELLS
CELL_HEIGHT = IMAGE_HEIGHT / HEIGHT_CELLS

THREADS = 1

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Concatenate, UpSampling2D, Conv2D, Reshape
from tensorflow.keras.models import Model


def create_model(trainable=True):
    model = MobileNet(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), include_top=False, alpha=ALPHA, weights="imagenet")
    for layer in model.layers:
        layer.trainable = trainable
    # model.summary()
    block_2 = model.get_layer("conv_pw_1_relu").output
    block_1 = model.get_layer("conv_pw_1_relu").output
    block0 = model.get_layer("conv_pw_3_relu").output
    block1 = model.get_layer("conv_pw_5_relu").output
    block2 = model.get_layer("conv_pw_11_relu").output
    block3 = model.get_layer("conv_pw_13_relu").output

    x = Concatenate()([UpSampling2D()(block3), block2])
    print(x.shape)
    x = Concatenate()([UpSampling2D()(x), block1])
    print(x.shape)
    x = Concatenate()([UpSampling2D()(x), block0])
    print(x.shape)
    x = Concatenate()([UpSampling2D()(x), block_1])
    print(x.shape)
    x = UpSampling2D()(x)
    print(x.shape)
    x = Conv2D(1, kernel_size=1, activation="sigmoid")(x)
    x = Reshape((IMAGE_HEIGHT, IMAGE_WIDTH))(x)
    print(x.shape)
    return Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Call the create_model function

# %%
# Give trainable=False as argument, if you want to freeze lower layers for fast training (but low accuracy)
model = create_model()

# Print summary
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 1s 0us/step
# (?, 14, 14, 1536)
# (?, 28, 28, 1792)
# (?, 56, 56, 1920)
# (?, 112, 112, 1984)
# (?, 224, 224, 1984)
# (?, 224, 224)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 112, 112, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 112, 112, 32) 288         conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 112, 112, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (ReLU)           (None, 112, 112, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 112, 112, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 112, 112, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (ReLU)           (None, 112, 112, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 113, 113, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 56, 56, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 56, 56, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (ReLU)           (None, 56, 56, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 56, 56, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 56, 56, 128)  1152        conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 56, 56, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 57, 57, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 28, 28, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (ReLU)           (None, 28, 28, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 28, 28, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 28, 28, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 29, 29, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (ReLU)           (None, 14, 14, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 14, 14, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 15, 15, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 7, 7, 512)    4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 7, 7, 512)    2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, 7, 7, 512)    0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 7, 7, 1024)   524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 7, 7, 1024)   9216        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, 7, 7, 1024)   1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 14, 14, 1024) 0           conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1536) 0           up_sampling2d[0][0]
#                                                                  conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 1536) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 1792) 0           up_sampling2d_1[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 56, 56, 1792) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 1920) 0           up_sampling2d_2[0][0]
#                                                                  conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 112, 112, 192 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 198 0           up_sampling2d_3[0][0]
#                                                                  conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 224, 224, 198 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 1)  1985        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 224, 224)     0           conv2d[0][0]
# ==================================================================================================
# Total params: 3,230,849
# Trainable params: 3,208,961
# Non-trainable params: 21,888
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define dice coefficient function (5 marks)
# - Create a function to calculate dice coefficient

# %%
def dice_coefficient(y_true, y_pred):
    #### Add your code here ####
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return numerator / (denominator + tf.keras.backend.epsilon()) #### Add your code here ####

# %% [markdown]
# ### Define loss

# %%
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.backend import log, epsilon
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - log(dice_coefficient(y_true, y_pred) + epsilon())

# %% [markdown]
# ### Compile the model (5 marks)
# - Complie the model using below parameters
#   - loss: use the loss function defined above
#   - optimizers: use Adam optimizer
#   - metrics: use dice_coefficient function defined above

# %%
# train_datagen = X_train  #### Add your code here ####
# validation_datagen = masks

optimizer = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.001, amsgrad=False)

model.compile(loss=loss, optimizer=optimizer, metrics=[dice_coefficient,'accuracy'])

# %% [markdown]
# ### Define checkpoint and earlystopping

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
checkpoint = ModelCheckpoint("model-{loss:.2f}.h5", monitor="loss", verbose=1, save_best_only=True,
                             save_weights_only=True, mode="min", period=1)
stop = EarlyStopping(monitor="loss", patience=5, mode="min")
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.2, patience=5, min_lr=1e-6, verbose=1, mode="min")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.

# %% [markdown]
# ### Fit the model (5 marks)
# - Fit the model using below parameters
#   - epochs: you can decide
#   - batch_size: 1
#   - callbacks: checkpoint, reduce_lr, stop

# %%
model.fit(X_train, masks, epochs= EPOCHS, batch_size= BATCH_SIZE, verbose=True, workers=THREADS,callbacks=[checkpoint, reduce_lr, stop],use_multiprocessing=True,validation_split=0.1)
# Out:
# Train on 368 samples, validate on 41 samples
# Epoch 1/50
# 366/368 [============================>.] - ETA: 0s - loss: 0.2977 - dice_coefficient: 0.8344 - acc: 0.0214
# Epoch 00001: loss did not improve from 0.29552
# 368/368 [==============================] - 15s 42ms/sample - loss: 0.2976 - dice_coefficient: 0.8341 - acc: 0.0213 - val_loss: 0.5357 - val_dice_coefficient: 0.7095 - val_acc: 0.0134
# Epoch 2/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2967 - dice_coefficient: 0.8346 - acc: 0.0214
# Epoch 00002: loss did not improve from 0.29552
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2965 - dice_coefficient: 0.8348 - acc: 0.0213 - val_loss: 0.5310 - val_dice_coefficient: 0.7123 - val_acc: 0.0158
# Epoch 3/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2962 - dice_coefficient: 0.8351 - acc: 0.0217
# Epoch 00003: loss did not improve from 0.29552
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2959 - dice_coefficient: 0.8352 - acc: 0.0216 - val_loss: 0.5496 - val_dice_coefficient: 0.7055 - val_acc: 0.0151
# Epoch 4/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2954 - dice_coefficient: 0.8355 - acc: 0.0217
# Epoch 00004: loss improved from 0.29552 to 0.29509, saving model to model-0.30.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2951 - dice_coefficient: 0.8357 - acc: 0.0217 - val_loss: 0.5430 - val_dice_coefficient: 0.7085 - val_acc: 0.0154
# Epoch 5/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2944 - dice_coefficient: 0.8361 - acc: 0.0221
# Epoch 00005: loss improved from 0.29509 to 0.29435, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2943 - dice_coefficient: 0.8361 - acc: 0.0220 - val_loss: 0.5519 - val_dice_coefficient: 0.7048 - val_acc: 0.0162
# Epoch 6/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2938 - dice_coefficient: 0.8365 - acc: 0.0222
# Epoch 00006: loss improved from 0.29435 to 0.29369, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2937 - dice_coefficient: 0.8365 - acc: 0.0222 - val_loss: 0.5430 - val_dice_coefficient: 0.7080 - val_acc: 0.0154
# Epoch 7/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2931 - dice_coefficient: 0.8368 - acc: 0.0217
# Epoch 00007: loss improved from 0.29369 to 0.29301, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2930 - dice_coefficient: 0.8369 - acc: 0.0224 - val_loss: 0.5294 - val_dice_coefficient: 0.7128 - val_acc: 0.0132
# Epoch 8/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2919 - dice_coefficient: 0.8375 - acc: 0.0225
# Epoch 00008: loss improved from 0.29301 to 0.29193, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2919 - dice_coefficient: 0.8375 - acc: 0.0225 - val_loss: 0.5589 - val_dice_coefficient: 0.7024 - val_acc: 0.0160
# Epoch 9/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2913 - dice_coefficient: 0.8381 - acc: 0.0227
# Epoch 00009: loss improved from 0.29193 to 0.29133, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2913 - dice_coefficient: 0.8380 - acc: 0.0226 - val_loss: 0.5397 - val_dice_coefficient: 0.7096 - val_acc: 0.0156
# Epoch 10/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2916 - dice_coefficient: 0.8379 - acc: 0.0231
# Epoch 00010: loss improved from 0.29133 to 0.29089, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2909 - dice_coefficient: 0.8382 - acc: 0.0231 - val_loss: 0.5562 - val_dice_coefficient: 0.7044 - val_acc: 0.0193
# Epoch 11/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2902 - dice_coefficient: 0.8387 - acc: 0.0231
# Epoch 00011: loss improved from 0.29089 to 0.28980, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2898 - dice_coefficient: 0.8389 - acc: 0.0230 - val_loss: 0.5496 - val_dice_coefficient: 0.7056 - val_acc: 0.0193
# Epoch 12/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2896 - dice_coefficient: 0.8390 - acc: 0.0231
# Epoch 00012: loss improved from 0.28980 to 0.28928, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2893 - dice_coefficient: 0.8392 - acc: 0.0231 - val_loss: 0.5605 - val_dice_coefficient: 0.7021 - val_acc: 0.0171
# Epoch 13/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2887 - dice_coefficient: 0.8396 - acc: 0.0233
# Epoch 00013: loss improved from 0.28928 to 0.28873, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2887 - dice_coefficient: 0.8395 - acc: 0.0233 - val_loss: 0.5406 - val_dice_coefficient: 0.7101 - val_acc: 0.0160
# Epoch 14/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2884 - dice_coefficient: 0.8399 - acc: 0.0236
# Epoch 00014: loss improved from 0.28873 to 0.28825, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2882 - dice_coefficient: 0.8398 - acc: 0.0236 - val_loss: 0.5518 - val_dice_coefficient: 0.7053 - val_acc: 0.0180
# Epoch 15/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2879 - dice_coefficient: 0.8400 - acc: 0.0235
# Epoch 00015: loss improved from 0.28825 to 0.28770, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2877 - dice_coefficient: 0.8401 - acc: 0.0234 - val_loss: 0.5533 - val_dice_coefficient: 0.7059 - val_acc: 0.0175
# Epoch 16/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2871 - dice_coefficient: 0.8407 - acc: 0.0237
# Epoch 00016: loss improved from 0.28770 to 0.28700, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2870 - dice_coefficient: 0.8406 - acc: 0.0237 - val_loss: 0.5432 - val_dice_coefficient: 0.7081 - val_acc: 0.0182
# Epoch 17/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2862 - dice_coefficient: 0.8412 - acc: 0.0240
# Epoch 00017: loss improved from 0.28700 to 0.28631, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2863 - dice_coefficient: 0.8410 - acc: 0.0239 - val_loss: 0.5693 - val_dice_coefficient: 0.7004 - val_acc: 0.0225
# Epoch 18/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2859 - dice_coefficient: 0.8415 - acc: 0.0239
# Epoch 00018: loss improved from 0.28631 to 0.28578, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2858 - dice_coefficient: 0.8413 - acc: 0.0239 - val_loss: 0.5457 - val_dice_coefficient: 0.7076 - val_acc: 0.0156
# Epoch 19/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2852 - dice_coefficient: 0.8419 - acc: 0.0241
# Epoch 00019: loss improved from 0.28578 to 0.28513, saving model to model-0.29.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2851 - dice_coefficient: 0.8418 - acc: 0.0240 - val_loss: 0.5531 - val_dice_coefficient: 0.7048 - val_acc: 0.0177
# Epoch 20/50
# 366/368 [============================>.] - ETA: 0s - loss: 0.2842 - dice_coefficient: 0.8422 - acc: 0.0239
# Epoch 00020: loss improved from 0.28513 to 0.28442, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2844 - dice_coefficient: 0.8422 - acc: 0.0239 - val_loss: 0.5536 - val_dice_coefficient: 0.7061 - val_acc: 0.0182
# Epoch 21/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2842 - dice_coefficient: 0.8424 - acc: 0.0240
# Epoch 00021: loss improved from 0.28442 to 0.28405, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2840 - dice_coefficient: 0.8424 - acc: 0.0243 - val_loss: 0.5668 - val_dice_coefficient: 0.7010 - val_acc: 0.0186
# Epoch 22/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2839 - dice_coefficient: 0.8427 - acc: 0.0248
# Epoch 00022: loss improved from 0.28405 to 0.28381, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2838 - dice_coefficient: 0.8425 - acc: 0.0248 - val_loss: 0.5453 - val_dice_coefficient: 0.7086 - val_acc: 0.0167
# Epoch 23/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2831 - dice_coefficient: 0.8428 - acc: 0.0238
# Epoch 00023: loss improved from 0.28381 to 0.28303, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2830 - dice_coefficient: 0.8430 - acc: 0.0245 - val_loss: 0.5560 - val_dice_coefficient: 0.7060 - val_acc: 0.0173
# Epoch 24/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2828 - dice_coefficient: 0.8433 - acc: 0.0248
# Epoch 00024: loss improved from 0.28303 to 0.28262, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2826 - dice_coefficient: 0.8433 - acc: 0.0247 - val_loss: 0.5495 - val_dice_coefficient: 0.7071 - val_acc: 0.0193
# Epoch 25/50
# 366/368 [============================>.] - ETA: 0s - loss: 0.2825 - dice_coefficient: 0.8434 - acc: 0.0247
# Epoch 00025: loss improved from 0.28262 to 0.28198, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2820 - dice_coefficient: 0.8436 - acc: 0.0246 - val_loss: 0.5424 - val_dice_coefficient: 0.7100 - val_acc: 0.0175
# Epoch 26/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2814 - dice_coefficient: 0.8443 - acc: 0.0249
# Epoch 00026: loss improved from 0.28198 to 0.28158, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2816 - dice_coefficient: 0.8440 - acc: 0.0249 - val_loss: 0.5516 - val_dice_coefficient: 0.7067 - val_acc: 0.0171
# Epoch 27/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2807 - dice_coefficient: 0.8446 - acc: 0.0250
# Epoch 00027: loss improved from 0.28158 to 0.28095, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2810 - dice_coefficient: 0.8443 - acc: 0.0250 - val_loss: 0.5377 - val_dice_coefficient: 0.7114 - val_acc: 0.0177
# Epoch 28/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2807 - dice_coefficient: 0.8447 - acc: 0.0251
# Epoch 00028: loss improved from 0.28095 to 0.28070, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2807 - dice_coefficient: 0.8445 - acc: 0.0251 - val_loss: 0.5585 - val_dice_coefficient: 0.7042 - val_acc: 0.0188
# Epoch 29/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2804 - dice_coefficient: 0.8448 - acc: 0.0252
# Epoch 00029: loss improved from 0.28070 to 0.28003, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2800 - dice_coefficient: 0.8448 - acc: 0.0251 - val_loss: 0.5422 - val_dice_coefficient: 0.7104 - val_acc: 0.0204
# Epoch 30/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2796 - dice_coefficient: 0.8454 - acc: 0.0254
# Epoch 00030: loss improved from 0.28003 to 0.27968, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2797 - dice_coefficient: 0.8451 - acc: 0.0254 - val_loss: 0.5428 - val_dice_coefficient: 0.7100 - val_acc: 0.0180
# Epoch 31/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2794 - dice_coefficient: 0.8454 - acc: 0.0255
# Epoch 00031: loss improved from 0.27968 to 0.27920, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2792 - dice_coefficient: 0.8454 - acc: 0.0255 - val_loss: 0.5593 - val_dice_coefficient: 0.7052 - val_acc: 0.0204
# Epoch 32/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2790 - dice_coefficient: 0.8456 - acc: 0.0256
# Epoch 00032: loss improved from 0.27920 to 0.27890, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2789 - dice_coefficient: 0.8456 - acc: 0.0255 - val_loss: 0.5456 - val_dice_coefficient: 0.7092 - val_acc: 0.0195
# Epoch 33/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2783 - dice_coefficient: 0.8461 - acc: 0.0255
# Epoch 00033: loss improved from 0.27890 to 0.27828, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 42ms/sample - loss: 0.2783 - dice_coefficient: 0.8460 - acc: 0.0255 - val_loss: 0.5686 - val_dice_coefficient: 0.7019 - val_acc: 0.0208
# Epoch 34/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2783 - dice_coefficient: 0.8461 - acc: 0.0259
# Epoch 00034: loss improved from 0.27828 to 0.27796, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2780 - dice_coefficient: 0.8462 - acc: 0.0258 - val_loss: 0.5472 - val_dice_coefficient: 0.7098 - val_acc: 0.0182
# Epoch 35/50
# 366/368 [============================>.] - ETA: 0s - loss: 0.2775 - dice_coefficient: 0.8465 - acc: 0.0259
# Epoch 00035: loss improved from 0.27796 to 0.27747, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2775 - dice_coefficient: 0.8464 - acc: 0.0258 - val_loss: 0.5558 - val_dice_coefficient: 0.7058 - val_acc: 0.0195
# Epoch 36/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2340 - dice_coefficient: 0.8490 - acc: 0.0262
# Epoch 00036: loss improved from 0.27747 to 0.27712, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 42ms/sample - loss: 0.2771 - dice_coefficient: 0.8467 - acc: 0.0261 - val_loss: 0.5367 - val_dice_coefficient: 0.7144 - val_acc: 0.0180
# Epoch 37/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2765 - dice_coefficient: 0.8470 - acc: 0.0261
# Epoch 00037: loss improved from 0.27712 to 0.27665, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2766 - dice_coefficient: 0.8469 - acc: 0.0260 - val_loss: 0.5518 - val_dice_coefficient: 0.7076 - val_acc: 0.0186
# Epoch 38/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2766 - dice_coefficient: 0.8470 - acc: 0.0257
# Epoch 00038: loss improved from 0.27665 to 0.27630, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2763 - dice_coefficient: 0.8473 - acc: 0.0260 - val_loss: 0.5493 - val_dice_coefficient: 0.7081 - val_acc: 0.0180
# Epoch 39/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2760 - dice_coefficient: 0.8474 - acc: 0.0261
# Epoch 00039: loss improved from 0.27630 to 0.27593, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2759 - dice_coefficient: 0.8474 - acc: 0.0261 - val_loss: 0.5486 - val_dice_coefficient: 0.7094 - val_acc: 0.0188
# Epoch 40/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2755 - dice_coefficient: 0.8477 - acc: 0.0263
# Epoch 00040: loss improved from 0.27593 to 0.27551, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2755 - dice_coefficient: 0.8478 - acc: 0.0263 - val_loss: 0.5550 - val_dice_coefficient: 0.7063 - val_acc: 0.0199
# Epoch 41/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2752 - dice_coefficient: 0.8479 - acc: 0.0263
# Epoch 00041: loss improved from 0.27551 to 0.27508, saving model to model-0.28.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2751 - dice_coefficient: 0.8479 - acc: 0.0263 - val_loss: 0.5465 - val_dice_coefficient: 0.7115 - val_acc: 0.0197
# Epoch 42/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2748 - dice_coefficient: 0.8483 - acc: 0.0266
# Epoch 00042: loss improved from 0.27508 to 0.27479, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2748 - dice_coefficient: 0.8482 - acc: 0.0265 - val_loss: 0.5661 - val_dice_coefficient: 0.7030 - val_acc: 0.0191
# Epoch 43/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2742 - dice_coefficient: 0.8485 - acc: 0.0265
# Epoch 00043: loss improved from 0.27479 to 0.27428, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2743 - dice_coefficient: 0.8484 - acc: 0.0266 - val_loss: 0.5596 - val_dice_coefficient: 0.7056 - val_acc: 0.0195
# Epoch 44/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2743 - dice_coefficient: 0.8486 - acc: 0.0270
# Epoch 00044: loss improved from 0.27428 to 0.27399, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2740 - dice_coefficient: 0.8487 - acc: 0.0269 - val_loss: 0.5673 - val_dice_coefficient: 0.7043 - val_acc: 0.0215
# Epoch 45/50
# 366/368 [============================>.] - ETA: 0s - loss: 0.2739 - dice_coefficient: 0.8487 - acc: 0.0268
# Epoch 00045: loss improved from 0.27399 to 0.27359, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2736 - dice_coefficient: 0.8489 - acc: 0.0270 - val_loss: 0.5516 - val_dice_coefficient: 0.7083 - val_acc: 0.0219
# Epoch 46/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2734 - dice_coefficient: 0.8491 - acc: 0.0271
# Epoch 00046: loss improved from 0.27359 to 0.27336, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2734 - dice_coefficient: 0.8491 - acc: 0.0270 - val_loss: 0.5622 - val_dice_coefficient: 0.7046 - val_acc: 0.0193
# Epoch 47/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2729 - dice_coefficient: 0.8496 - acc: 0.0275
# Epoch 00047: loss improved from 0.27336 to 0.27298, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2730 - dice_coefficient: 0.8493 - acc: 0.0274 - val_loss: 0.5607 - val_dice_coefficient: 0.7054 - val_acc: 0.0197
# Epoch 48/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2726 - dice_coefficient: 0.8495 - acc: 0.0266
# Epoch 00048: loss improved from 0.27298 to 0.27266, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 41ms/sample - loss: 0.2727 - dice_coefficient: 0.8495 - acc: 0.0273 - val_loss: 0.5675 - val_dice_coefficient: 0.7043 - val_acc: 0.0219
# Epoch 49/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2724 - dice_coefficient: 0.8496 - acc: 0.0266
# Epoch 00049: loss improved from 0.27266 to 0.27230, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2723 - dice_coefficient: 0.8497 - acc: 0.0273 - val_loss: 0.5909 - val_dice_coefficient: 0.6961 - val_acc: 0.0225
# Epoch 50/50
# 367/368 [============================>.] - ETA: 0s - loss: 0.2720 - dice_coefficient: 0.8501 - acc: 0.0274
# Epoch 00050: loss improved from 0.27230 to 0.27196, saving model to model-0.27.h5
# 368/368 [==============================] - 15s 40ms/sample - loss: 0.2720 - dice_coefficient: 0.8500 - acc: 0.0274 - val_loss: 0.5695 - val_dice_coefficient: 0.7030 - val_acc: 0.0217

# %% [markdown]
# ### Get the predicted mask for a sample image   (5 marks)

# %%
model.load_weights("model-0.27.h5")

# %%
print(model.input_shape,)
print(model.output_shape)
print(X_train.shape)
# Out:
# (None, 224, 224, 3)
# (None, 224, 224)
# (409, 224, 224, 3)

# %%
n = 13
sample_image = X_train[n]
print(sample_image.shape)
pyplot.imshow(sample_image)

#### Add your code here ####
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
sample_image = np.resize(sample_image, (1, 224, 224, 3))
print(sample_image.shape)
pred_face = model.predict(sample_image,)
print(pred_face.shape)
pred_face = np.resize(pred_face, (224, 224))
pyplot.imshow(pred_face)
# Out:
# (1, 224, 224, 3)
# (1, 224, 224)

# %% [markdown]
# ### Impose the mask on the image (5 marks)

# %%
imp_pred_face = np.resize(pred_face, (224,224))
res_image = np.resize(sample_image,  (224,224,3))
pyplot.imshow(res_image)

# %%
#### Add your code here ####
pyplot.imshow(imp_pred_face, alpha=0.5)

fig = plt.figure(frameon=False)
im1 = plt.imshow(res_image)
im2 = plt.imshow(imp_pred_face,alpha=.6)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
